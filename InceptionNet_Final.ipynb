# %% [markdown]
# ### InceptionNet

# %%
import os
import glob
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.callbacks import Callback, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ### Examining the data

# %%
dataset_paths = ['./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/',
                 './input/deepfake-and-real-images/Dataset/',
                 './input/real-vs-ai-generated-faces-dataset/dataset/dataset/']

# %%
status_map = {'0' : 'real',
              '1' : 'fake',
              'real' : 'real',
              'fake' : 'fake'}

where_map = {'test' : 'test',
             'train' : 'train',
             'valid' : 'valid',
             'validation' : 'valid',
             'validate' : 'valid'}

# %%
pd.options.display.max_colwidth = 100

dataset = {"image_path":[],"img_status":[],"where":[]}
for path in dataset_paths:
    for where in os.listdir(path):
        for status in os.listdir(path+"/"+where):
            for image in glob.glob(path+where+"/"+status+"/"+"*.jpg"):
                dataset["image_path"].append(image)
                dataset["img_status"].append(status_map.get(status.lower()))
                dataset["where"].append(where_map.get(where.lower()))

dataset = pd.DataFrame(dataset)
dataset
# Out:
#                                                                                          image_path  \
# 0               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\00276TOPP4.jpg
# 1               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\008BYSE725.jpg
# 2               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\009ZTJ3621.jpg
# 3               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\00F8LKY6JC.jpg
# 4               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\00JEP4Z36Z.jpg
# ...                                                                                             ...
# 451284  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004978.jpg
# 451285  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004979.jpg
# 451286  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004980.jpg
# 451287  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004988.jpg
# 451288  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004998.jpg
#
#        img_status  where
# 0            fake   test
# 1            fake   test
# 2            fake   test
# 3            fake   test
# 4            fake   test
# ...           ...    ...
# 451284       fake  valid
# 451285       fake  valid
# 451286       fake  valid
# 451287       fake  valid
# 451288       fake  valid
#
# [451289 rows x 3 columns]

# %%
print(dataset.value_counts("img_status"),'\n')
print(dataset.value_counts("where"))
# Out:
# img_status
# real    235201
# fake    216088
# Name: count, dtype: int64
#
# where
# train    312576
# valid     83618
# test      55095
# Name: count, dtype: int64

# %%
plt.figure(figsize = (14,10))
for i in range(9):
    random = np.random.randint(1,len(dataset))
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(dataset.loc[random,"image_path"]))
    plt.title(dataset.loc[random, "img_status"], size = 10) 
    plt.xticks([])
    plt.yticks([])
    
plt.show()

# %% [markdown]
# ### Processing the data

# %%
test_df = dataset[dataset['where'] == 'test'].drop('where', axis=1)
valid_df = dataset[dataset['where'] == 'valid'].drop('where', axis=1)
train_df = dataset[dataset['where'] == 'train'].drop('where', axis=1)

# %%
output_path = "./output/"

try:
    os.mkdir(output_path + "model/")
except OSError as error:
    print(error) 

try:
    os.mkdir(output_path + "model/cp/")
except OSError as error:
    print(error) 

model_dir = output_path + "model/"
checkpoint_dir = model_dir + "cp/"

# %%
tf.random.set_seed(42)
img_height = 224
img_width = 224

train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.05,
    zoom_range=0.1,
    horizontal_flip=True)

valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                               directory=None,
                                               x_col='image_path',
                                               y_col='img_status',
                                               batch_size=32,
                                               target_size=(img_height, img_width),
                                               class_mode="binary",
                                               seed=42)

valid_data = valid_datagen.flow_from_dataframe(dataframe=valid_df,
                                               directory=None,
                                               x_col='image_path',
                                               y_col='img_status',
                                               batch_size=32,
                                               target_size=(img_height, img_width),
                                               class_mode="binary",
                                               seed=42)

test_data = test_datagen.flow_from_dataframe(dataframe=test_df,
                                               directory=None,
                                               x_col='image_path',
                                               y_col='img_status',
                                               batch_size=1,
                                               target_size=(img_height, img_width),
                                               class_mode="binary",
                                               shuffle=False,
                                               seed=42)
# Out:
# Found 312576 validated image filenames belonging to 2 classes.
# Found 83618 validated image filenames belonging to 2 classes.
# Found 55095 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Create and train the model

# %%
model_name = "inception_model"

def create_model():
    base_model = InceptionV3(
        include_top = False, 
        weights = 'imagenet',
        input_shape = (224, 224, 3)
    )
    #base_model.trainable = False
    model = Sequential([base_model,
                        layers.GlobalAveragePooling2D(),
                        layers.Dense(512,activation='relu'),
                        layers.Dropout(0.2),
                        layers.Dense(128,activation='relu'),
                        layers.Dropout(0.2),
                        layers.Dense(1, activation='sigmoid')
                        ])
    model.compile(
        optimizer=Adam(learning_rate=0.0005), 
        loss='binary_crossentropy', 
        metrics=['accuracy']
    )   
    return model

# %%
model = create_model()

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 6s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 22,917,665
# Trainable params: 22,883,233
# Non-trainable params: 34,432
# _________________________________________________________________

# %% [markdown]
# ### Model checkpoint

# %%
def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()

# %%
checkpoint_path = checkpoint_dir + model_name +"_cp.keras"

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                 factor=0.2,
                                                 verbose=1,
                                                 patience=2)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                     min_delta=0.01,
                                                     patience=4,
                                                     verbose=1,
                                                     restore_best_weights=True
                                                    )

# %%
model_history = model.fit(train_data,
    epochs = 16,
    steps_per_epoch = 1024,
    validation_data = valid_data,
    validation_steps = 1024,
    callbacks = [checkpoint_cb, reduce_lr, early_stopping_cb] 
)
# Out:
# Epoch 1/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.3962 - accuracy: 0.8135
# Epoch 1: val_loss improved from inf to 1.14969, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 252s 239ms/step - loss: 0.3962 - accuracy: 0.8135 - val_loss: 1.1497 - val_accuracy: 0.6194 - lr: 5.0000e-04
# Epoch 2/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.8970
# Epoch 2: val_loss improved from 1.14969 to 0.25351, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 257s 251ms/step - loss: 0.2535 - accuracy: 0.8970 - val_loss: 0.2535 - val_accuracy: 0.8926 - lr: 5.0000e-04
# Epoch 3/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.2031 - accuracy: 0.9202
# Epoch 3: val_loss did not improve from 0.25351
# 1024/1024 [==============================] - 232s 227ms/step - loss: 0.2031 - accuracy: 0.9202 - val_loss: 0.3972 - val_accuracy: 0.8627 - lr: 5.0000e-04
# Epoch 4/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9286
# Epoch 4: val_loss improved from 0.25351 to 0.19479, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 242s 236ms/step - loss: 0.1816 - accuracy: 0.9286 - val_loss: 0.1948 - val_accuracy: 0.9186 - lr: 5.0000e-04
# Epoch 5/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9358
# Epoch 5: val_loss did not improve from 0.19479
# 1024/1024 [==============================] - 260s 254ms/step - loss: 0.1659 - accuracy: 0.9358 - val_loss: 0.3806 - val_accuracy: 0.8336 - lr: 5.0000e-04
# Epoch 6/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9403
# Epoch 6: val_loss did not improve from 0.19479
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1024/1024 [==============================] - 268s 261ms/step - loss: 0.1504 - accuracy: 0.9403 - val_loss: 0.2103 - val_accuracy: 0.9159 - lr: 5.0000e-04
# Epoch 7/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9650
# Epoch 7: val_loss did not improve from 0.19479
# 1024/1024 [==============================] - 287s 280ms/step - loss: 0.0958 - accuracy: 0.9650 - val_loss: 0.2059 - val_accuracy: 0.9214 - lr: 1.0000e-04
# Epoch 8/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9699
# Epoch 8: val_loss improved from 0.19479 to 0.14260, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 264s 258ms/step - loss: 0.0829 - accuracy: 0.9699 - val_loss: 0.1426 - val_accuracy: 0.9461 - lr: 1.0000e-04
# Epoch 9/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9695
# Epoch 9: val_loss did not improve from 0.14260
# 1024/1024 [==============================] - 263s 257ms/step - loss: 0.0796 - accuracy: 0.9695 - val_loss: 0.1760 - val_accuracy: 0.9324 - lr: 1.0000e-04
# Epoch 10/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9745
# Epoch 10: val_loss improved from 0.14260 to 0.14194, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 260s 254ms/step - loss: 0.0701 - accuracy: 0.9745 - val_loss: 0.1419 - val_accuracy: 0.9431 - lr: 1.0000e-04
# Epoch 11/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9732
# Epoch 11: val_loss improved from 0.14194 to 0.11054, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 266s 260ms/step - loss: 0.0728 - accuracy: 0.9732 - val_loss: 0.1105 - val_accuracy: 0.9592 - lr: 1.0000e-04
# Epoch 12/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9760
# Epoch 12: val_loss improved from 0.11054 to 0.09606, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 253s 247ms/step - loss: 0.0655 - accuracy: 0.9760 - val_loss: 0.0961 - val_accuracy: 0.9637 - lr: 1.0000e-04
# Epoch 13/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9755
# Epoch 13: val_loss did not improve from 0.09606
# 1024/1024 [==============================] - 275s 269ms/step - loss: 0.0631 - accuracy: 0.9755 - val_loss: 0.1766 - val_accuracy: 0.9425 - lr: 1.0000e-04
# Epoch 14/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9780
# Epoch 14: val_loss did not improve from 0.09606
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 1024/1024 [==============================] - 297s 290ms/step - loss: 0.0598 - accuracy: 0.9780 - val_loss: 0.1328 - val_accuracy: 0.9514 - lr: 1.0000e-04
# Epoch 15/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9819
# Epoch 15: val_loss did not improve from 0.09606
# 1024/1024 [==============================] - 300s 293ms/step - loss: 0.0508 - accuracy: 0.9819 - val_loss: 0.0989 - val_accuracy: 0.9654 - lr: 2.0000e-05
# Epoch 16/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9826
# Epoch 16: val_loss improved from 0.09606 to 0.08246, saving model to ./output/model/cp\inception_model_cp.keras
# 1024/1024 [==============================] - 287s 280ms/step - loss: 0.0469 - accuracy: 0.9826 - val_loss: 0.0825 - val_accuracy: 0.9704 - lr: 2.0000e-05

# %%
plot_hist(model_history)

# %% [markdown]
# ### Evaluate the model

# %%
# Plot the validation and training data separately
def plot_loss_curves(history):
    """
    Returns separate loss curves for training and validation metrics.
    """ 
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss']))

    # Plot loss
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.figure()
    plt.plot(epochs, accuracy, label='training_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend()

# %%
plot_loss_curves(model_history)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# func to generate different score and confusion matrix from test score.
def gen_test_data(model):
    # Generate Confusion Matrix
    y_pred = model.predict(test_data)
    y_test = test_data.classes
    
#     y_pred_labels = np.argmax(y_pred, axis=1)
    y_pred_labels = (y_pred > 0.5).astype(np.float32)

    confusion_mat = confusion_matrix(y_test, y_pred_labels)
    print(confusion_mat)
    
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_mat, display_labels = [False, True])

    cm_display.plot(cmap="Blues")
    plt.show()
    
    # Get AUC, ROC and Precision Score
    print("ROC AUC Score:", metrics.roc_auc_score(y_test, y_pred))
    print("AP Score:", metrics.average_precision_score(y_test, y_pred))
    print()
    print(metrics.classification_report(y_test, y_pred_labels))
    accu = np.sum(np.equal(y_test, y_pred_labels.reshape(-1))) / len(y_test)
    print('Final Test Acccuracy = {:.3f}'.format(accu*100))

# %%
gen_test_data(model)
# Out:
# 55095/55095 [==============================] - 500s 9ms/step
# [[24421  1261]
#  [ 1398 28015]]
# ROC AUC Score: 0.9905084742612448
# AP Score: 0.9917047113151514
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     25682
#            1       0.96      0.95      0.95     29413
#
#     accuracy                           0.95     55095
#    macro avg       0.95      0.95      0.95     55095
# weighted avg       0.95      0.95      0.95     55095
#
# Final Test Acccuracy = 95.174

# %%
best_model = load_model(checkpoint_path)

# %%
gen_test_data(best_model)

# %%
model.save(model_dir + model_name + "_last.keras")
best_model.save(model_dir + model_name + "_best.keras")

# %% [markdown]
# ### Inference

# %%
model = load_model(model_dir + model_name + "_last.keras")

# %%
gen_test_data(model)
# Out:
# 55095/55095 [==============================] - 577s 10ms/step
# [[24274  1408]
#  [ 1278 28135]]
# ROC AUC Score: 0.9903694934151603
# AP Score: 0.9915001058845269
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     25682
#            1       0.95      0.96      0.95     29413
#
#     accuracy                           0.95     55095
#    macro avg       0.95      0.95      0.95     55095
# weighted avg       0.95      0.95      0.95     55095
#
# Final Test Acccuracy = 95.125

# %% [markdown]
# ### Predict custom images

# %%
def load_image(img_path, show=True):

    img = load_img(img_path, target_size=(224,224))
    img_tensor = img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    img_tensor /= 255.

    if show:
        plt.imshow(img_tensor[0])
        plt.axis('off')
        plt.show()

    return img_tensor

# %%
def pred_img(image_tensor, model):
    pred = model.predict(image_tensor)
    prob = pred.reshape(-1)[0]
    label = 'Real' if prob > 0.5 else 'Fake'
    print(f"\nReal: {prob:.10f}")
    print(f"Fake: {1-prob:.10f}")
    print(f"\nFinal Prediction: {label}")
