# %% [markdown]
# ### ResNet

# %%
import os
import glob
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import Callback, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ### Examining the data

# %%
dataset_paths = ['./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/',
                 './input/deepfake-and-real-images/Dataset/',
                 './input/real-vs-ai-generated-faces-dataset/dataset/dataset/']

# %%
status_map = {'0' : 'real',
              '1' : 'fake',
              'real' : 'real',
              'fake' : 'fake'}

where_map = {'test' : 'test',
             'train' : 'train',
             'valid' : 'valid',
             'validation' : 'valid',
             'validate' : 'valid'}

# %%
pd.options.display.max_colwidth = 100

dataset = {"image_path":[],"img_status":[],"where":[]}
for path in dataset_paths:
    for where in os.listdir(path):
        for status in os.listdir(path+"/"+where):
            for image in glob.glob(path+where+"/"+status+"/"+"*.jpg"):
                dataset["image_path"].append(image)
                dataset["img_status"].append(status_map.get(status.lower()))
                dataset["where"].append(where_map.get(where.lower()))

dataset = pd.DataFrame(dataset)
dataset
# Out:
#                                                                                          image_path  \
# 0               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\00276TOPP4.jpg
# 1               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\008BYSE725.jpg
# 2               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\009ZTJ3621.jpg
# 3               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\00F8LKY6JC.jpg
# 4               ./input/140k-real-and-fake-faces/real_vs_fake/real-vs-fake/test/fake\00JEP4Z36Z.jpg
# ...                                                                                             ...
# 451284  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004978.jpg
# 451285  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004979.jpg
# 451286  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004980.jpg
# 451287  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004988.jpg
# 451288  ./input/real-vs-ai-generated-faces-dataset/dataset/dataset/validate/1\SFHQ_pt4_00004998.jpg
#
#        img_status  where
# 0            fake   test
# 1            fake   test
# 2            fake   test
# 3            fake   test
# 4            fake   test
# ...           ...    ...
# 451284       fake  valid
# 451285       fake  valid
# 451286       fake  valid
# 451287       fake  valid
# 451288       fake  valid
#
# [451289 rows x 3 columns]

# %%
print(dataset.value_counts("img_status"),'\n')
print(dataset.value_counts("where"))
# Out:
# img_status
# real    235201
# fake    216088
# Name: count, dtype: int64
#
# where
# train    312576
# valid     83618
# test      55095
# Name: count, dtype: int64

# %%
plt.figure(figsize = (14,10))
for i in range(9):
    random = np.random.randint(1,len(dataset))
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(dataset.loc[random,"image_path"]))
    plt.title(dataset.loc[random, "img_status"], size = 10) 
    plt.xticks([])
    plt.yticks([])
    
plt.show()

# %% [markdown]
# ### Processing the data

# %%
test_df = dataset[dataset['where'] == 'test'].drop('where', axis=1)
valid_df = dataset[dataset['where'] == 'valid'].drop('where', axis=1)
train_df = dataset[dataset['where'] == 'train'].drop('where', axis=1)

# %%
output_path = "./output/"

try:
    os.mkdir(output_path + "model/")
except OSError as error:
    print(error) 

try:
    os.mkdir(output_path + "model/cp/")
except OSError as error:
    print(error) 

model_dir = output_path + "model/"
checkpoint_dir = model_dir + "cp/"

# %%
tf.random.set_seed(42)
img_height = 224
img_width = 224

train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.05,
    zoom_range=0.1,
    horizontal_flip=True)

valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                               directory=None,
                                               x_col='image_path',
                                               y_col='img_status',
                                               batch_size=32,
                                               target_size=(img_height, img_width),
                                               class_mode="binary",
                                               seed=42)

valid_data = valid_datagen.flow_from_dataframe(dataframe=valid_df,
                                               directory=None,
                                               x_col='image_path',
                                               y_col='img_status',
                                               batch_size=32,
                                               target_size=(img_height, img_width),
                                               class_mode="binary",
                                               seed=42)

test_data = test_datagen.flow_from_dataframe(dataframe=test_df,
                                               directory=None,
                                               x_col='image_path',
                                               y_col='img_status',
                                               batch_size=1,
                                               target_size=(img_height, img_width),
                                               class_mode="binary",
                                               shuffle=False,
                                               seed=42)
# Out:
# Found 312576 validated image filenames belonging to 2 classes.
# Found 83618 validated image filenames belonging to 2 classes.
# Found 55095 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Create and train the model

# %%
model_name = "resnet_model"

def create_model():
    base_model = ResNet50(
        include_top = False, 
        weights = 'imagenet',
        input_shape = (224, 224, 3)
    )
    #base_model.trainable = False
    model = Sequential([base_model,
                        layers.GlobalAveragePooling2D(),
                        layers.Dense(512,activation='relu'),
                        layers.Dropout(0.2),
                        layers.Dense(128,activation='relu'),
                        layers.Dropout(0.2),
                        layers.Dense(1, activation='sigmoid')
                        ])
    model.compile(
        optimizer=Adam(learning_rate=0.0005), 
        loss='binary_crossentropy', 
        metrics=['accuracy']
    )   
    return model

# %%
model = create_model()

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_4   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 512)               1049088
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 128)               65664
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 24,702,593
# Trainable params: 24,649,473
# Non-trainable params: 53,120
# _________________________________________________________________

# %% [markdown]
# ### Model checkpoint

# %%
def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()

# %%
checkpoint_path = checkpoint_dir + model_name +"_cp.keras"

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                 factor=0.2,
                                                 verbose=1,
                                                 patience=2)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                     min_delta=0.01,
                                                     patience=4,
                                                     verbose=1,
                                                     restore_best_weights=True
                                                    )

# %%
model_history = model.fit(train_data,
    epochs = 16,
    steps_per_epoch = 1024,
    validation_data = valid_data,
    validation_steps = 1024,
    callbacks = [checkpoint_cb, reduce_lr, early_stopping_cb] 
)
# Out:
# Epoch 1/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.4427 - accuracy: 0.7905
# Epoch 1: val_loss improved from inf to 0.68851, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 319s 307ms/step - loss: 0.4427 - accuracy: 0.7905 - val_loss: 0.6885 - val_accuracy: 0.7323 - lr: 5.0000e-04
# Epoch 2/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.8670
# Epoch 2: val_loss improved from 0.68851 to 0.44694, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 314s 307ms/step - loss: 0.3091 - accuracy: 0.8670 - val_loss: 0.4469 - val_accuracy: 0.7980 - lr: 5.0000e-04
# Epoch 3/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.8869
# Epoch 3: val_loss did not improve from 0.44694
# 1024/1024 [==============================] - 314s 306ms/step - loss: 0.2714 - accuracy: 0.8869 - val_loss: 0.5265 - val_accuracy: 0.7514 - lr: 5.0000e-04
# Epoch 4/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.9007
# Epoch 4: val_loss did not improve from 0.44694
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1024/1024 [==============================] - 313s 306ms/step - loss: 0.2444 - accuracy: 0.9007 - val_loss: 1.1914 - val_accuracy: 0.6161 - lr: 5.0000e-04
# Epoch 5/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9349
# Epoch 5: val_loss improved from 0.44694 to 0.27076, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 314s 306ms/step - loss: 0.1643 - accuracy: 0.9349 - val_loss: 0.2708 - val_accuracy: 0.8849 - lr: 1.0000e-04
# Epoch 6/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9427
# Epoch 6: val_loss did not improve from 0.27076
# 1024/1024 [==============================] - 315s 307ms/step - loss: 0.1465 - accuracy: 0.9427 - val_loss: 0.2746 - val_accuracy: 0.8877 - lr: 1.0000e-04
# Epoch 7/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9481
# Epoch 7: val_loss improved from 0.27076 to 0.23255, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 317s 309ms/step - loss: 0.1334 - accuracy: 0.9481 - val_loss: 0.2325 - val_accuracy: 0.9037 - lr: 1.0000e-04
# Epoch 8/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9521
# Epoch 8: val_loss did not improve from 0.23255
# 1024/1024 [==============================] - 316s 309ms/step - loss: 0.1237 - accuracy: 0.9521 - val_loss: 0.5163 - val_accuracy: 0.8027 - lr: 1.0000e-04
# Epoch 9/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9537
# Epoch 9: val_loss did not improve from 0.23255
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 1024/1024 [==============================] - 314s 306ms/step - loss: 0.1190 - accuracy: 0.9537 - val_loss: 0.3111 - val_accuracy: 0.8720 - lr: 1.0000e-04
# Epoch 10/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9624
# Epoch 10: val_loss improved from 0.23255 to 0.19246, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 314s 306ms/step - loss: 0.1012 - accuracy: 0.9624 - val_loss: 0.1925 - val_accuracy: 0.9266 - lr: 2.0000e-05
# Epoch 11/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9645
# Epoch 11: val_loss did not improve from 0.19246
# 1024/1024 [==============================] - 313s 306ms/step - loss: 0.0960 - accuracy: 0.9645 - val_loss: 0.2228 - val_accuracy: 0.9185 - lr: 2.0000e-05
# Epoch 12/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9652
# Epoch 12: val_loss improved from 0.19246 to 0.17404, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 314s 307ms/step - loss: 0.0919 - accuracy: 0.9652 - val_loss: 0.1740 - val_accuracy: 0.9336 - lr: 2.0000e-05
# Epoch 13/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9649
# Epoch 13: val_loss improved from 0.17404 to 0.16938, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 314s 306ms/step - loss: 0.0924 - accuracy: 0.9649 - val_loss: 0.1694 - val_accuracy: 0.9350 - lr: 2.0000e-05
# Epoch 14/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9663
# Epoch 14: val_loss did not improve from 0.16938
# 1024/1024 [==============================] - 313s 306ms/step - loss: 0.0871 - accuracy: 0.9663 - val_loss: 0.2765 - val_accuracy: 0.8956 - lr: 2.0000e-05
# Epoch 15/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9676
# Epoch 15: val_loss did not improve from 0.16938
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
# 1024/1024 [==============================] - 313s 306ms/step - loss: 0.0865 - accuracy: 0.9676 - val_loss: 0.2927 - val_accuracy: 0.8945 - lr: 2.0000e-05
# Epoch 16/16
# 1024/1024 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9698
# Epoch 16: val_loss improved from 0.16938 to 0.14448, saving model to ./output/model/cp\resnet_model_cp.keras
# 1024/1024 [==============================] - 314s 307ms/step - loss: 0.0828 - accuracy: 0.9698 - val_loss: 0.1445 - val_accuracy: 0.9450 - lr: 4.0000e-06

# %%
plot_hist(model_history)

# %% [markdown]
# ### Evaluate the model

# %%
# Plot the validation and training data separately
def plot_loss_curves(history):
    """
    Returns separate loss curves for training and validation metrics.
    """ 
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss']))

    # Plot loss
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.figure()
    plt.plot(epochs, accuracy, label='training_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend()

# %%
plot_loss_curves(model_history)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# func to generate different score and confusion matrix from test score.
def gen_test_data(model):
    # Generate Confusion Matrix
    y_pred = model.predict(test_data)
    y_test = test_data.classes
    
#     y_pred_labels = np.argmax(y_pred, axis=1)
    y_pred_labels = (y_pred > 0.5).astype(np.float32)

    confusion_mat = confusion_matrix(y_test, y_pred_labels)
    print(confusion_mat)
    
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_mat, display_labels = [False, True])

    cm_display.plot(cmap="Blues")
    plt.show()
    
    # Get AUC, ROC and Precision Score
    print("ROC AUC Score:", metrics.roc_auc_score(y_test, y_pred))
    print("AP Score:", metrics.average_precision_score(y_test, y_pred))
    print()
    print(metrics.classification_report(y_test, y_pred_labels))
    accu = np.sum(np.equal(y_test, y_pred_labels.reshape(-1))) / len(y_test)
    print('Final Test Acccuracy = {:.3f}'.format(accu*100))

# %%
gen_test_data(model)
# Out:
# 55095/55095 [==============================] - 317s 6ms/step
# [[22604  3078]
#  [ 1521 27892]]
# ROC AUC Score: 0.9748554910432877
# AP Score: 0.9787167720508663
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     25682
#            1       0.90      0.95      0.92     29413
#
#     accuracy                           0.92     55095
#    macro avg       0.92      0.91      0.92     55095
# weighted avg       0.92      0.92      0.92     55095
#
# Final Test Acccuracy = 91.653

# %%
best_model = load_model(checkpoint_path)

# %%
gen_test_data(best_model)

# %%
model.save(model_dir + model_name + "_last.keras")
best_model.save(model_dir + model_name + "_best.keras")

# %% [markdown]
# ### Inference

# %%
model = load_model(model_dir + model_name + "_last.keras")

# %%
gen_test_data(model)
# Out:
# 55095/55095 [==============================] - 379s 7ms/step
# [[22604  3078]
#  [ 1521 27892]]
# ROC AUC Score: 0.9748554910432877
# AP Score: 0.9787167720508663
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     25682
#            1       0.90      0.95      0.92     29413
#
#     accuracy                           0.92     55095
#    macro avg       0.92      0.91      0.92     55095
# weighted avg       0.92      0.92      0.92     55095
#
# Final Test Acccuracy = 91.653

# %% [markdown]
# ### Predict custom images

# %%
def load_image(img_path, show=True):

    img = load_img(img_path, target_size=(224,224))
    img_tensor = img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    img_tensor /= 255.

    if show:
        plt.imshow(img_tensor[0])
        plt.axis('off')
        plt.show()

    return img_tensor

# %%
def pred_img(image_tensor, model):
    pred = model.predict(image_tensor)
    prob = pred.reshape(-1)[0]
    label = 'Real' if prob > 0.5 else 'Fake'
    print(f"\nReal: {prob:.10f}")
    print(f"Fake: {1-prob:.10f}")
    print(f"\nFinal Prediction: {label}")
